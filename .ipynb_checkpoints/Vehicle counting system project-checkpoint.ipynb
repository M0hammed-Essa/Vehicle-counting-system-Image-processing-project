# %% [markdown]
# # Vehicle counting system project

# %% [markdown]
# ## Idea description
#
# This project presents an automated vehicle counting system using image processing and computer vision techniques. The system analyzes video frames or image sequences from a traffic scene to detect and count moving vehicles such as cars, trucks, and buses.
#
# It applies background subtraction to separate moving objects from the static environment, followed by noise reduction and morphological operations to improve detection accuracy. Once vehicles are identified, the system tracks and counts them over time.
#
# The output provides the total number of vehicles, which can be used for traffic monitoring, congestion analysis, and smart city applications.
#
# ##### **Images source: https://www.kaggle.com/datasets/bratjay/ua-detrac-orig/data**
# ##### **Project Repository on GitHub: https://github.com/M0hammed-Essa/Vehicle-counting-system-Image-processing-project/blob/main/README.md**

# %% [markdown]
# ## Vehicle Counting System Pipeline
#
# The following pipeline illustrates the step-by-step process of the vehicle counting system, starting from input video acquisition to final vehicle counting and output generation. Each stage represents a key processing step in the system workflow.
#
#
# <img src="Display Images/Vehicle Counting System Pipeline.png" width="500"  align="left"/>

# %% [markdown]
# ## Flow diagram
#
# The flow diagram below shows the overall architecture of the vehicle counting system. It demonstrates how video input is processed through multiple stages including preprocessing.
#
#
#
#
# <img src="Display Images/flow diagram of Vehicle counting system.png" width="700"  align="center"/>

# %% [markdown]
# ___________________________________________________________________________________________________________________________

# %% [markdown]
# ## libraries

# %%
import cv2 # video processing, detection, tracking (main library)
import numpy # image arrays + calculations
import matplotlib.pyplot # plotting results (graphs)
import pandas # storing/exporting vehicle counts
import scipy.ndimage # advanced image filtering

# import YOLO → AI-based object detection (optional upgrade)
